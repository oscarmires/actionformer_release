# %% [markdown]
# # Preparation

# %% [markdown]
# ## Install dependencies

# %%
# !pip install torch==1.11
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 750.6 MB 11 kB/s
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.1+cu113
#     Uninstalling torch-1.12.1+cu113:
#       Successfully uninstalled torch-1.12.1+cu113
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.13.1+cu113 requires torch==1.12.1, but you have torch 1.11.0 which is incompatible.
# torchtext 0.13.1 requires torch==1.12.1, but you have torch 1.11.0 which is incompatible.
# torchaudio 0.12.1+cu113 requires torch==1.12.1, but you have torch 1.11.0 which is incompatible.
# ...

# %%
# !pip install tensorboard numpy PyYAML pandas h5py joblib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# ## GCC requirements

# %%
# !gcc --version
# Out:
# gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
# Copyright (C) 2017 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# %cd ./libs/utils
# !python setup.py install --user
# %cd ../..
# Out:
# /content/actionformer_release/libs/utils
# running install
# running bdist_egg
# running egg_info
# creating nms_1d_cpu.egg-info
# writing nms_1d_cpu.egg-info/PKG-INFO
# writing dependency_links to nms_1d_cpu.egg-info/dependency_links.txt
# writing top-level names to nms_1d_cpu.egg-info/top_level.txt
# writing manifest file 'nms_1d_cpu.egg-info/SOURCES.txt'
# /usr/local/lib/python3.7/dist-packages/torch/utils/cpp_extension.py:411: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#   warnings.warn(msg.format('we could not find ninja.'))
# writing manifest file 'nms_1d_cpu.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_ext
# building 'nms_1d_cpu' extension
# creating build
# creating build/temp.linux-x86_64-3.7
# creating build/temp.linux-x86_64-3.7/csrc
# ...

# %% [markdown]
# ## Download repo

# %%
# !git clone https://github.com/oscarmires/actionformer_release.git
# %cd actionformer_release
# Out:
# Cloning into 'actionformer_release'...
# remote: Enumerating objects: 271, done.
# remote: Counting objects: 100% (48/48), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 271 (delta 29), reused 27 (delta 21), pack-reused 223
# Receiving objects: 100% (271/271), 607.70 KiB | 1.57 MiB/s, done.
# Resolving deltas: 100% (129/129), done.
# /content/actionformer_release

# %% [markdown]
# ## Get dataset via Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# Before running the next cell, copy the dataset from https://drive.google.com/file/d/1VW8px1Nz9A17i0wMVUfxh6YsPCLVqL-S/view?usp=sharing into your Drive.

# %%
# %cd /content/actionformer_release/
# !mkdir data
# %cd data

# Change the path to the directory where you copied the dataset:
# !tar -xf /content/drive/MyDrive/a_ag2022/ActionFormer/anet_1.3.tar.gz -C .

# %% [markdown]
# ## Install pretrained model

# %% [markdown]
# Before running the next cell, copy the pretrained model from https://drive.google.com/file/d/1JKh3w14ngAjgzuuP22BnjhkhIcBSqteJ/view?usp=sharing into your Drive.

# %%
# %cd /content/actionformer_release/
# !mkdir pretrained
# %cd pretrained

# Change the path to the directory where you copied the pretrained model:
# !unzip /content/drive/MyDrive/a_ag2022/ActionFormer/anet_tsp_reproduce_v3.zip -d .
# Out:
# /content/actionformer_release
# /content/actionformer_release/pretrained
# Archive:  /content/drive/MyDrive/a_ag2022/ActionFormer/anet_tsp_reproduce_v3.zip
#    creating: ./anet_tsp_reproduce/
#   inflating: ./anet_tsp_reproduce/anet_tsp_reproduce_log.txt
#   inflating: ./anet_tsp_reproduce/anet_tsp_reproduce_results.txt
#    creating: ./anet_tsp_reproduce/logs/
#   inflating: ./anet_tsp_reproduce/logs/events.out.tfevents.1659359717.yinli-MS-7D19.7710.0
#    creating: ./anet_tsp_reproduce/logs/train_all_losses_cls_loss/
#   inflating: ./anet_tsp_reproduce/logs/train_all_losses_cls_loss/events.out.tfevents.1659359727.yinli-MS-7D19.7710.1
#    creating: ./anet_tsp_reproduce/logs/train_all_losses_reg_loss/
#   inflating: ./anet_tsp_reproduce/logs/train_all_losses_reg_loss/events.out.tfevents.1659359727.yinli-MS-7D19.7710.2
#   inflating: ./anet_tsp_reproduce/config.txt
#   inflating: ./anet_tsp_reproduce/epoch_014.pth.tar

# %% [markdown]
# # Evaluate Pretrained Model

# %%
# %cd /content/actionformer_release

# !python ./eval.py ./configs/anet_tsp.yaml ./pretrained/anet_tsp_reproduce/
# Out:
# /content/actionformer_release
# {'dataset': {'crop_ratio': [0.9, 1.0],
#              'default_fps': 15,
#              'downsample_rate': 1,
#              'feat_folder': './data/anet_1.3/tsp_features',
#              'feat_stride': 16,
#              'file_ext': '.npy',
#              'file_prefix': 'v_',
#              'force_upsampling': True,
#              'input_dim': 512,
#              'json_file': './data/anet_1.3/annotations/anet1.3_tsp_filtered.json',
#              'max_seq_len': 192,
#              'num_classes': 1,
#              'num_frames': 16,
#              'trunc_thresh': 0.5},
#  'dataset_name': 'anet',
#  'devices': ['cuda:0'],
#  'init_rand_seed': 1234567891,
#  'loader': {'batch_size': 16, 'num_workers': 4},
#  'model': {'backbone_arch': (2, 2, 5),
#            'backbone_type': 'convTransformer',
#            'embd_dim': 256,
#            'embd_kernel_size': 3,
#            'embd_with_ln': True,
#            'fpn_dim': 256,
#            'fpn_start_level': 0,
# ...
